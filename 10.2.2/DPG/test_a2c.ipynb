# %%
from standard_env import StandardEnv, TelescopeEnv
from A2C import  A2CAgent
import torch

env = StandardEnv(
    T = 300,
    I_max = 20,
    lambd = 50/300,
    Delta = 0.01,
    phi = 1e-6, # 1e-6
    varphi = 1e-2, # 1e-2
    sigma = 1e-3, 
    gamma = 1, 
    S_0 = 20,
    X_0 = 0,
    q_0 = 0,
)

tenv = TelescopeEnv(
    T = 300,
    I_max = 20,
    lambd = 50/300,
    Delta = 0.01,
    phi = 1e-6, # 1e-6
    varphi = 1e-2, # 1e-2
    sigma = 1e-3, 
    gamma = 1, 
    S_0 = 20,
    X_0 = 0,
    q_0 = 0)
agent = A2CAgent(env=tenv, gamma=0.99, lr_actor=1e-5, lr_critic=1e-4, n_layers=6, n_nodes=256, entropy_coef=0.03)

# %%
agent.train(n_iter=20000, n_plot=5000, mini_batch_size=128, n_iter_Q=1, n_iter_pi=1)
