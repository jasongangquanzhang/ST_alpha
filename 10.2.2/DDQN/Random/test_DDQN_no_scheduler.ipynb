# %%
from env_standard_random import StandardEnv
from DDQN_standard_random import DDQNAgent

env = StandardEnv(
    T = 300,
    I_max = 20,
    lambd = 50/300,
    Delta = 0.01,
    phi = 0.000001, # working good but no buy and sell
    varphi = 0.01,
    sigma = 0.001,
    gamma = 0.999,
    S_0 = 20,
    X_0 = 0,
    q_0 = 0
)
# TODO try gamma = 1
# TODO try update_every = 1
# TODO try tau = 1
# TODO try sample_size = 100 (lower)
# TODO try lower phi maybe e-6
# TODO more nodes
agent = DDQNAgent(
    env=env, state_size = 4, action_size = 4, seed=42, lr=1e-3,
    tau=1e-3, update_every=4, sample_size=1_000, capacity=1_000_000, name='trial',
    n_nodes=16, n_hidden_layers=6
)
# Out:
# Entering DDQNAgent.__init__

# %%
agent.train(n_iter=5_000, n_plot=500, eps_start=1.0, eps_end=0.01, eps_decay=0.999, batch_size=500)
# Out:
#  10%|█         | 500/5000 [00:07<00:58, 77.09it/s]
# Replay Buffer Size: 250500
# Iteration 500, Epsilon: 0.6057725659163237, Total Reward: -0.0010436907177791
#  20%|█▉        | 996/5000 [00:20<01:03, 63.13it/s]
# Replay Buffer Size: 500500
# Iteration 1000, Epsilon: 0.36732772934619257, Total Reward: 0.012718326412141323
#  30%|██▉       | 1496/5000 [00:33<00:58, 60.21it/s]
# Replay Buffer Size: 750500
# Iteration 1500, Epsilon: 0.22273980093919937, Total Reward: 0.013477219268679619
#  40%|███▉      | 1996/5000 [00:50<00:59, 50.82it/s]
# Replay Buffer Size: 1000000
# Iteration 2000, Epsilon: 0.13506472547210188, Total Reward: 0.01328945904970169
#  50%|████▉     | 2496/5000 [01:03<00:47, 52.99it/s]
# Replay Buffer Size: 1000000
# Iteration 2500, Epsilon: 0.08190040571973876, Total Reward: 0.015634797513484955
#  60%|█████▉    | 2996/5000 [01:19<00:37, 53.75it/s]
# Replay Buffer Size: 1000000
# Iteration 3000, Epsilon: 0.049662681604038215, Total Reward: 0.007856667041778564
# ...
