# %%
from env_standard_random import StandardEnv
from DDQN_standard_random import DDQNAgent

env = StandardEnv(
    T = 300,
    I_max = 20,
    lambd = 50/300,
    Delta = 0.01,
    phi = 1e-6,
    varphi = 7e-4,
    sigma = 0.001,
    gamma = 1,
    S_0 = 20,
    X_0 = 0,
    q_0 = 0
)

agent = DDQNAgent(
    env=env, state_size = 2, action_size = 4, seed=42, lr=1e-3,
    weight_decay=0.01, sched_step_size=500/1, sched_gamma = 0.99,
    tau=1e-3, update_every=1, sample_size=6_000, capacity=1_000_000, name='trial',
    n_nodes=32, n_hidden_layers=4     
)
# Out:
# Entering DDQNAgent.__init__

# %%
agent.train(n_iter=5_000, n_plot=500, eps_start=1.0, eps_end=0.01, eps_decay=0.999, batch_size=512)
# agent.train(n_iter=5_000, n_plot=500, eps_start=1.0, eps_end=0.01, eps_decay=0.999, batch_size=1)
# Out:
#  10%|█         | 500/5000 [00:26<04:55, 15.21it/s]
# Replay Buffer Size: 256512
# Learning Rate: 0.001
# Iteration 500, Epsilon: 0.6057725659163237, Total Reward: -0.0016656804364174604
#  20%|██        | 1000/5000 [01:10<05:12, 12.79it/s]
# Replay Buffer Size: 512512
# Learning Rate: 0.00099
# Iteration 1000, Epsilon: 0.36732772934619257, Total Reward: 0.0011181773152202368
#  30%|███       | 1500/5000 [01:59<05:24, 10.77it/s]
# Replay Buffer Size: 768512
# Learning Rate: 0.0009801
# Iteration 1500, Epsilon: 0.22273980093919937, Total Reward: 0.0006829893682152033
#  40%|████      | 2000/5000 [03:00<05:09,  9.68it/s]
# Replay Buffer Size: 1000000
# Learning Rate: 0.000970299
# Iteration 2000, Epsilon: 0.13506472547210188, Total Reward: 0.0014683768386021256
#  50%|█████     | 2500/5000 [03:55<04:29,  9.29it/s]
# Replay Buffer Size: 1000000
# Learning Rate: 0.0009605960099999999
# Iteration 2500, Epsilon: 0.08190040571973876, Total Reward: 0.000988299143500626
# ...
